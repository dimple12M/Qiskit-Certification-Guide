# %% [markdown]
# This section consists:
#
# # <a href=.\Multi_qubit_states.ipynb>Representation of multiple qubit states</a>
#
# # Multiple Qubit gates
#
# - 2-qubit gates
# - 3-Qubit gates

# %% [markdown]
# References:
#
# Qiskit textbook Reference:
# 1. https://qiskit.org/textbook/ch-gates/multiple-qubits-entangled-states.html
#
# Qiskit Documentation:
#
# 2. https://qiskit.org/documentation/tutorials/circuits/3_summary_of_quantum_operations.html
#
# IBM Operations Glossary
#
# 3.https://quantum-computing.ibm.com/composer/docs/iqx/operations_glossary

# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from math import pi

# %% [markdown]
# ***
#
# <h1>2-Qubit gates</h1>
# <h2> Also called as Controlled Gates</h2>
# <ol>
#     <li> CX </li>
#     <li> CY </li>
#     <li> CZ </li>
#     <li> Controlled Hadamard </li>
#     <li> Controlled Phase </li>
# </ol>
#
# ***

# %% [markdown]
# ## SWAP(not a controlled type)

# %% [markdown]
# ## <a href="Controlled_rotations.ipynb" >Controlled Rotations: CRx,Cry,Crz</a>

# %% [markdown]
# ## <a href="3_Qubit_gates.ipynb" >3-Qubit Gates</a>

# %% [markdown]
# ***
# # Controlled NOT Gate : CX
# ***
# ### Also called as controlled-x gate
# ### conditional gate
# ### Syntax: cx(control,target)
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CXGate.html#qiskit.circuit.library.CXGate

# %% [markdown]
# ### CASE 1: q0 is control, q1 is target

# %%
qc=QuantumCircuit(2)
qc.cx(0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cx gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]

# %% [markdown]
# ### CASE 2: q1 is control, q0 is target

# %%
qc=QuantumCircuit(2)
qc.cx(1,0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cx gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]]

# %% [markdown]
# ### Operation: cx gate flips the target qubit if the control qubit is in |1> state

# %%
qc=QuantumCircuit(2)
qc.cx(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)

# %%
print(state)
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2))

# %%
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cx_gate_00.png](attachment:cx_gate_00.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Note: To see the change on the target qubit , control qubit has input as X gate

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.cx(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cx_1.png](attachment:cx_1.png)
# Reference: IBM Quantum Composer

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.cx(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cx_2.png](attachment:cx_2.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Controlled Y Gate : CY
# ***

# %% [markdown]
# ### Syntax: cx(control,target)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CYGate.html#qiskit.circuit.library.CYGate

# %%
qc=QuantumCircuit(2)
qc.cy(0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cy gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.-0.j 0.-0.j 0.-0.j 0.-1.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+1.j 0.+0.j 0.+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cy_gate_00.png](attachment:cy_gate_00.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Note: Target qubit is applied Y gate when the Control qubit is in |1> state

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.cy(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & i  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cy_gate.png](attachment:cy_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Controlled Z Gate : CZ
# ***
#
# IMP:
# 1. It is a clifford gate
# 2. It is also symmetric

# %% [markdown]
# ### Syntax: cz(control,target)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CZGate.html#qiskit.circuit.library.CZGate

# %%
qc=QuantumCircuit(2)
qc.cz(0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cz gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [-0.+0.j -0.+0.j -0.+0.j -1.+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cy_gate_00.png](attachment:cy_gate_00.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Note: Flips the phase of the target qubit when the Control qubit is in |1> state

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.x(1)
qc.cz(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & -1  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cz_gate.png](attachment:cz_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Controlled Hadamard Gate : CH
# ***

# %% [markdown]
# ### Syntax: ch(control,target)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CHGate.html#qiskit.circuit.library.CHGate

# %%
qc=QuantumCircuit(2)
qc.ch(0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for ch gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 1.   -0.j  0.   +0.j -0.   +0.j  0.   +0.j]
#  [ 0.   +0.j  0.707-0.j  0.   +0.j  0.707-0.j]
#  [ 0.   -0.j -0.   +0.j  1.   +0.j -0.   +0.j]
#  [-0.   +0.j  0.707+0.j -0.   +0.j -0.707+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cy_gate_00.png](attachment:cy_gate_00.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Note: Applies H to the target qubit when the Control qubit is in |1> state

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.ch(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & \tfrac{1}{\sqrt{2}} & 0 & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![ch_gate.png](attachment:ch_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Controlled Phase Gate : CP
# ***
#
# ### Diagonal
# ### Symmetric

# %% [markdown]
# ### Syntax: cp(control,target)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CPhaseGate.html#qiskit.circuit.library.CPhaseGate

# %%
qc=QuantumCircuit(2)
qc.cp(pi/2,0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cp gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+1.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cy_gate_00.png](attachment:cy_gate_00.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Note: Flips the phase of the target qubit when the Control qubit is in |1> state

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.x(1)
qc.cp(pi/2,0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & i  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cp_gate.png](attachment:cp_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Swap Gate : swap(qubit_1,qubit_2)
# ***
#
# IMP:
# 1. It is a clifford gate
# 2. It is also symmetric
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.SwapGate.html#qiskit.circuit.library.SwapGate
#
# ### swaps/exchanges the states of the 2 qubits

# %%
qc=QuantumCircuit(2)
qc.swap(0,1)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for swap gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Example:

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![swap_1.png](attachment:swap_1.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Now apply a swap gate

# %%
qc=QuantumCircuit(2)
qc.x(0)
qc.swap(0,1)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 1 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![swap_2.png](attachment:swap_2.png)
# Reference: IBM Quantum Composer
