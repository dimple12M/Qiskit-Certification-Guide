# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from math import pi

# %% [markdown]
# # Rotation Gates: RX, RY and RZ
# # Are Non-Clifford gates

# %% [markdown]
# ***
# # Rx gate:
# ***

# %% [markdown]
# -Rotation around x-axis
#
# -single-qubit rotation through angle θ(radians) around the x-axis

# %%
qc=QuantumCircuit(1)
qc.rx(pi/2,0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Rx gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.707+0.j    0.   -0.707j]
#  [0.   -0.707j 0.707+0.j   ]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}i  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Rx_gate_matrix.png](attachment:Rx_gate_matrix.png)

# %% [markdown]
# ![RX_gate.png](attachment:RX_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### If the qubit is in state |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.rx(pi/2,0)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# -\tfrac{1}{\sqrt{2}}i & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Rx_gate_input_1.png](attachment:Rx_gate_input_1.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Ry gate:
# ***

# %% [markdown]
# -Rotation around y-axis
#
# -single-qubit rotation through angle θ(radians) around the y-axis

# %%
qc=QuantumCircuit(1)
qc.ry(pi/2,0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Ry gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 0.707+0.j -0.707+0.j]
#  [ 0.707+0.j  0.707+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Ry_gate_matrix.png](attachment:Ry_gate_matrix.png)

# %% [markdown]
# ![Ry_gate.png](attachment:Ry_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### If the qubit is in state |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.ry(pi/2,0)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# -\tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Ry_gate_input_1.png](attachment:Ry_gate_input_1.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Rz gate:
# ***

# %% [markdown]
# -Rotation around z-axis
#
# -single-qubit rotation through angle θ(radians) around the z-axis

# %%
qc=QuantumCircuit(1)
qc.rz(pi/2,0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Rz gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.707-0.707j 0.   +0.j   ]
#  [0.   +0.j    0.707+0.707j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}}(1 - i) & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Rz_gate_matrix.png](attachment:Rz_gate_matrix.png)

# %% [markdown]
# ![Rz_gate.png](attachment:Rz_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### If the qubit is in state |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.rz(pi/2,0)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & \tfrac{1}{\sqrt{2}}(1 + i)  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![Rz_gate_input_1.png](attachment:Rz_gate_input_1.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# # Other cases:

# %% [markdown]
# ## Example 1: Rx(pi)=-iX

# %%
qc=QuantumCircuit(1)
qc.rx(pi,0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Rx gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.+0.j 0.-1.j]
#  [0.-1.j 0.+0.j]]

# %%
qc=QuantumCircuit(1)
qc.x(0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-X gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]

# %% [markdown]
# ## Example 2: Ry(pi)=-iY

# %%
qc=QuantumCircuit(1)
qc.ry(pi,0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Ry gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 0.+0.j -1.+0.j]
#  [ 1.+0.j  0.+0.j]]

# %%
qc=QuantumCircuit(1)
qc.y(0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Y gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.-0.j 0.-1.j]
#  [0.+1.j 0.+0.j]]

# %% [markdown]
# ## Example 3: Rz(pi)=-iZ

# %%
qc=QuantumCircuit(1)
qc.rz(pi,0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Rz gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[0.-1.j 0.+0.j]
#  [0.+0.j 0.+1.j]]

# %%
qc=QuantumCircuit(1)
qc.z(0)
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Z gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[ 1.+0.j  0.+0.j]
#  [-0.+0.j -1.+0.j]]
