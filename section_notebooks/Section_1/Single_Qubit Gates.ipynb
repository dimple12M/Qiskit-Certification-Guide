# %% [markdown]
# ***
# # Single Qubit Gates:
# ***

# %% [markdown]
# # [Pauli Gates:](#PauliGates)
# <ol>
#     <li> Pauli X gate</li>
#     <li> Pauli Y gate</li>
#     <li> Pauli Z gate</li>
# </ol>

# %% [markdown]
# # [Other Gates:](#other_gates)</h1>
# <ol>
#     <li> Hadamard gate</li>
#     <li> S gate</li>
#     <li> S dagger gate</li>
#     <li> T gate</li>
#     <li> T dagger gate</li>
# </ol>

# %% [markdown]
# ### Additional :<a href="./Circuit_identities.ipynb">Circuit identities</a>

# %% [markdown]
# <h1> <a href= ".\Rotation_Gates.ipynb"> Rotation gates</a></h1>
# <ol>
#     <li> Rx gate</li>
#     <li> Ry gate</li>
#     <li> Rz dagger gate</li>
# </ol>

# %% [markdown]
# # <a href="UGate.ipynb">U gate</a>

# %% [markdown]
# # <a href=./SingleGate_MultipleQubits.ipynb>How to apply single qubit gate to multiple Qubits</a>

# %% [markdown]
# # Qiskit textbook Reference:
#
# https://qiskit.org/textbook/ch-states/single-qubit-gates.html

# %% [markdown]
# # IBM Operations Glossary
#
# https://quantum-computing.ibm.com/composer/docs/iqx/operations_glossary#barrier-operation

# %% [markdown]
# <ol>
#     <li>Classical Gates</li>
#     <li>Quantum gates</li>
#     <li>Phase gates</li>
#     <li>Non-unitary</li>
#     <li>Hadamard gate</li>
# </ol>

# %% [markdown]
# <table style="width:70%">
# <tr>
# <th>Clifford Gates</th>
# <th>Non-Clifford Gates</th>
#     <th>Phase gates</th>
#
# </tr>
#
# <tr>
#     <td>Pauli gates (I, X, Y, Z)</td>
#     <td>T</td>
#     <td>Z</td>
#  </tr>
# <tr>
#     <td>phase (S)</td>
#     <td>Toffoli</td>
#     <td>P</td>
# </tr>
# <tr>
#     <td>Hadamard (H)</td>
#     <td></td>
#     <td>S</td>
#     </tr>
# <tr>
#     <td>controlled-Z (CZ)</td>
#     <td></td>
#     <td>Sdg</td>
# </tr>
# <tr>
#     <td>controlled-not (CNOT)</td>
#     <td></td>
#     <td>T</td>
# </tr>
# <tr>
#     <td>swap</td>
#     <td></td>
#     <td>Tdg</td>
# </tr>
#
# </table>

# %% [markdown]
# # Other References
# https://medium.com/quantum-untangled/visualizing-quantum-logic-gates-part-1-515bb7b58916
# This article gives the description about the representation on cartesian plane and bloch sphere for X and Z gates.

# %% [markdown]
# https://qiskit.org/documentation/tutorials/circuits/3_summary_of_quantum_operations.html

# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from math import pi
from qiskit.visualization import *

# %% [markdown]
# # <a id = "PauliGates"> Pauli Gates </a>

# %% [markdown]
# ***
# > # Pauli-X gate
# ***
#
# ### Also called as "NOT gate"-Classical Analagous
#
# ### Called as "bit-flip" gate
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.XGate.html#qiskit.circuit.library.XGate

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.draw(output="mpl")

# %% [markdown]
# ##  To understand about unitary refer to Section 6</a>

# %%
backend = Aer.get_backend('unitary_simulator')
job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-X gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![X%20gate.png](attachment:X%20gate.png)
#
#
# Reference: IBM Quantum Composer

# %% [markdown]
# ![X_gate%20Equation.png](attachment:X_gate%20Equation.png)

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.x(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-X gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ***
# > # Pauli-Y gate
# ***
#
#
#
# ## Equivalent to a   "bit-flip" and "Phase-flip" gate
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.YGate.html

# %%
qc=QuantumCircuit(1)
qc.y(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Y gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[0.-0.j, 0.-1.j],
#           [0.+1.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![Y%20gate.png](attachment:Y%20gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Y gate :
#    ## - Interchane state 0 and state 1
#    ## - apply a relative phase flip

# %% [markdown]
# ![Ygate_equation.png](attachment:Ygate_equation.png)

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.y(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Y gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[-0.-1.j,  0.-0.j],
#           [-0.+0.j,  0.+1.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$- i |0\rangle$$

# %% [markdown]
# ![Ygate_Bit_Phase_flip.png](attachment:Ygate_Bit_Phase_flip.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# > # Pauli-Z gate
# ***
#
#
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.ZGate.html#qiskit.circuit.library.ZGate

# %%
qc=QuantumCircuit(1)
qc.z(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Z gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [-0.+0.j, -1.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$ |0\rangle$$

# %% [markdown]
# ## Equivalent to a "Phase-flip" gate

# %% [markdown]
# ## Qubit initial state is |0>

# %%
qc=QuantumCircuit(1)
qc.z(0)
qc.draw(output="mpl")

# %% [markdown]
# ![Z%20gate.png](attachment:Z%20gate.png)
#
#
# Reference: IBM Quantum Composer

# %% [markdown]
# ![Z%20gate_equation.png](attachment:Z%20gate_equation.png)

# %% [markdown]
# ## Qubit Initial State is |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.z(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Pauli-Z gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 0.+0.j,  1.+0.j],
#           [-1.-0.j,  0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$- |1\rangle$$

# %% [markdown]
# ![Phaseflip.png](attachment:Phaseflip.png)
#
# Reference: IBM Quantum Composer

# %% [markdown]
# # <a id = "other_gates"> Other Gates </a>

# %% [markdown]
# ***
# > # Hadamard gate
# ***
#
#
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.HGate.html#qiskit.circuit.library.HGate

# %%
qc=QuantumCircuit(1)
qc.h(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Hadamard gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 0.707+0.j,  0.707-0.j],
#           [ 0.707+0.j, -0.707+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$

# %% [markdown]
# ![Hadamard_Gate.png](attachment:Hadamard_Gate.png)

# %% [markdown]
# ![H_gate_equation.png](attachment:H_gate_equation.png)

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.h(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Hadamard gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 0.707+0.j,  0.707+0.j],
#           [-0.707-0.j,  0.707+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![H_gate_minus_state.png](attachment:H_gate_minus_state.png)

# %% [markdown]
# ***
# > # S gate
# ***
#
# ## Induces a pi/2 phase
#
#
# ## Also called as Phase gate (P-gate)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.SGate.html#qiskit.circuit.library.SGate

# %% [markdown]
# ### Qubit initial state is |0> state

# %%
qc=QuantumCircuit(1)
qc.s(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for S gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.+0.j, 0.+0.j],
#           [0.+0.j, 0.+1.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![S_gate.png](attachment:S_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Qubit initial state is |1> state

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.s(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for S gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[0.-0.j, 1.-0.j],
#           [0.+1.j, 0.-0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![Sgate_piBY2_phase.png](attachment:Sgate_piBY2_phase.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Also called as Squareroot of Z gate
#
# ## Also SS=Z

# %%
qc=QuantumCircuit(1)
qc.s(0)
qc.s(0)
qc.draw(output="mpl")

backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for S dagger gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [ 0.-0.j, -1.-0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![S_S_equals_Z.png](attachment:S_S_equals_Z.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# > # S dagger (sdg gate)
# ***
#
# ## Induces -pi/2 phase
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.SdgGate.html#qiskit.circuit.library.SdgGate

# %% [markdown]
# ## S dagger is the conjugate transpose(or Hermitian transpose) of the S gate
#
# ## Inverse of the S gate
#
# ## Qubit initial state is |0>

# %%
qc=QuantumCircuit(1)
qc.sdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Sdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.+0.j, 0.+0.j],
#           [0.+0.j, 0.-1.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![S_daggger.png](attachment:S_daggger.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Qubit initial state is |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.sdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Sdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 0.+0.j,  1.-0.j],
#           [-0.-1.j,  0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![S%20dagger_-pi:2%20phase.png](attachment:S%20dagger_-pi:2%20phase.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Also called as Squareroot of Z gate
# ## Also SdgSdg=Z

# %%
qc=QuantumCircuit(1)
qc.sdg(0)
qc.sdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Sdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [ 0.-0.j, -1.-0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ***
# > # T gate
# ***
#
#  ## pi/4 phase
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.TGate.html#qiskit.circuit.library.TGate

# %% [markdown]
# ## Qubit initial state is |0>

# %%
qc=QuantumCircuit(1)
qc.t(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for T gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.   +0.j   , 0.   +0.j   ],
#           [0.   +0.j   , 0.707+0.707j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![T%20gate.png](attachment:T%20gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Qubit initial state is |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.t(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for T gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[0.   -0.j   , 1.   +0.j   ],
#           [0.707+0.707j, 0.   -0.j   ]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![T%20gate_piBy4.png](attachment:T%20gate_piBy4.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# > # T dagger gate (tdg)
# ***
#
# ## T dagger is the conjugate transpose(or Hermitian transpose) of the T gate
# ## -pi/4 phase
#
# ### Inverse of the T gate
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.TdgGate.html#qiskit.circuit.library.TdgGate

# %% [markdown]
# ## Qubit initial state is |0>

# %%
qc=QuantumCircuit(1)
qc.tdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Tdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.   +0.j   , 0.   +0.j   ],
#           [0.   +0.j   , 0.707-0.707j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![T_dagger.png](attachment:T_dagger.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## Qubit initial state is |1>

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.tdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Tdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[0.   +0.j   , 1.   +0.j   ],
#           [0.707-0.707j, 0.   +0.j   ]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![T-dagger_-piBy4.png](attachment:T-dagger_-piBy4.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ## T dagger(tdg) : Also called as forth root of the Z gate
#
# ## Also TdgTdgTdgTdg=Z

# %%
qc=QuantumCircuit(1)
qc.tdg(0)
qc.tdg(0)
qc.tdg(0)
qc.tdg(0)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Tdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [ 0.-0.j, -1.-0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
qc=QuantumCircuit(1)
qc.z(0)

backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for Tdg gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [-0.+0.j, -1.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ***
# > # P gate(theta)
# ***
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.PhaseGate.html#qiskit.circuit.library.PhaseGate

# %% [markdown]
# ## Phase gate
# ## Parametrized
# ## rotates by an angle theta around Z-axis

# %%
qc=QuantumCircuit(1)
qc.p(pi,0)

qc.draw(output="mpl")

# %% [markdown]
# ## Theta=pi
# ## We obtain Z gate

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for P gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 1.+0.j,  0.+0.j],
#           [-0.+0.j, -1.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
qc=QuantumCircuit(1)
qc.p(pi/2,0)

qc.draw(output="mpl")

# %% [markdown]
# ## Theta=pi/2
# ## We obtain S gate

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for P gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.+0.j, 0.+0.j],
#           [0.+0.j, 0.+1.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
qc=QuantumCircuit(1)
qc.p(pi/4,0)

qc.draw(output="mpl")

# %% [markdown]
# ## Theta=pi/4
# ## We obtain T gate

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for P gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.   +0.j   , 0.   +0.j   ],
#           [0.   +0.j   , 0.707+0.707j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ## Qubit is initialized in the |1> state

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.p(pi,0)

qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for P gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[ 0.+0.j,  1.+0.j],
#           [-1.-0.j,  0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %% [markdown]
# ![P_gate_pi.png](attachment:P_gate_pi.png)
# Reference: IBM Quantum Composer

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.p(pi/2,0)

qc.draw(output="mpl")

# %% [markdown]
# ![P_gate_piBy2png.png](attachment:P_gate_piBy2png.png)
# Reference: IBM Quantum Composer

# %%
qc=QuantumCircuit(1)
qc.x(0)
qc.p(pi/4,0)

qc.draw(output="mpl")

# %% [markdown]
# ![P_gate_piBy4.png](attachment:P_gate_piBy4.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# # Φ=0, we get identity operator

# %%
qc=QuantumCircuit(1)
qc.p(0,0)

qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for P gate
print(result.get_unitary(qc, decimals=3))
# Out:
# Operator([[1.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
I=result.get_unitary(qc, decimals=3)

array_to_latex(I)
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$
