# %% [markdown]
# ***
# # 3-Qubit gates:
# ***
#
# 1. Toffoli gate
# 2. Fredkin gate

# %% [markdown]
# ***
# # Toffoli gate
# ***
#
# ### 3-qubit gate
# SYNTAX: ccx(control,control,target)
#
#    https://qiskit.org/documentation/stubs/qiskit.circuit.library.CCXGate.html#qiskit.circuit.library.CCXGate

# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from math import pi

# %%
qc=QuantumCircuit(3)
qc.ccx(0,1,2)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for ccx gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0 & 0 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![ccx_000.png](attachment:ccx_000.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Target qubit is flipped only when the first 2 control qubits are in |1> state

# %%
qc=QuantumCircuit(3)
qc.x(0)
qc.x(1)
qc.ccx(0,1,2)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 0 & 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![ccx_gate.png](attachment:ccx_gate.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ***
# # Fredkin gate
# ***
#
# ### controlled swap gate
# SYNTAX: cswap(control,target1,target2)
#
# https://qiskit.org/documentation/stubs/qiskit.circuit.library.CSwapGate.html#qiskit.circuit.library.CSwapGate

# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from math import pi

# %%
qc=QuantumCircuit(3)
qc.cswap(0,1,2)
qc.draw(output="mpl")

# %%
backend = Aer.get_backend('unitary_simulator')

job = execute(qc, backend)
result = job.result()
#Obtain the unitary matrix for cswap gate
print(result.get_unitary(qc, decimals=3))
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0 & 0 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![ccx_000.png](attachment:ccx_000.png)
# Reference: IBM Quantum Composer

# %% [markdown]
# ### Target1 and Target 2 states are swappedonly when the  control qubit is in |1> state

# %%
qc=QuantumCircuit(3)
qc.x(0)
qc.x(1)
qc.cswap(0,1,2)
qc.draw(output="mpl")

# %%
state = Statevector.from_instruction(qc)
state.draw(output='latex')
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 0 & 0 & 1 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![cswap.png](attachment:cswap.png)
# Reference: IBM Quantum Composer
